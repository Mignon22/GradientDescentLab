# %%
import sys
import os
import numpy as np

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from gdlib.Ex1_42_adam_SGD import Ex1_42_adam_SGD
from gdlib.lr_grid_search import lr_grid_search

best_lr, df_lr = lr_grid_search(experiment_class = Ex1_42_adam_SGD, lr_start = 0.01, lr_end = 2, lr_step = 0.01, iterations = 25000, exp_kwargs = {})

print('Best LR = ', np.round(best_lr, 2))
display(df_lr.head(10))

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from gdlib.Ex1_43_adam_SGDR import Ex1_43_adam_SGDR
from gdlib.lr_grid_search import lr_grid_search

best_lr, df_lr = lr_grid_search(experiment_class = Ex1_43_adam_SGDR, lr_start = 0.02, lr_end = 1, lr_step = 0.01, iterations = 25000, exp_kwargs = {})

print(f'Best LR = {best_lr, 3}')
display(df_lr.head(10))

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root is not sys.path:
    sys.path.append(project_root)

from gdlib.Ex1_44_adam_minibatch import Ex1_44_adam_MB

from gdlib.lr_grid_search import lr_grid_search

best_lr, df_lr = lr_grid_search(experiment_class = Ex1_44_adam_MB, lr_start = 0.2, lr_end = 8, lr_step = 0.01, iterations = 25000, exp_kwargs = {})

print(f'Best LR = {best_lr, 2}')
display(df_lr.head(10))
