# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

from gdlib.Ex1_42_adam_SGD import Ex1_42_adam_SGD

exp42 = Ex1_42_adam_SGD(master_seed = 42)
min_test_loss, min_index, best_w, best_b, df_summary, loss_history_train, loss_history_test, lr_history = exp42.train_one_lr(initial_lr = 0.28, iterations = 25000, verbose = True)
display(df_summary)

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root is not sys.path:
    sys.path.append(project_root)

from gdlib.Ex1_43_adam_SGDR import Ex1_43_adam_SGDR

exp43 = Ex1_43_adam_SGDR(master_seed = 42)
min_test_loss, min_index, best_w, best_b, df_summary, loss_history_train, loss_history_test, lr_history = exp43.train_one_lr(initial_lr = 0.26, iterations = 25000)

display(df_summary)

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root is not sys.path:
    sys.path.append(project_root)

from gdlib.Ex1_44_adam_minibatch import Ex1_44_adam_MB

exp44 = Ex1_44_adam_MB(master_seed = 42)
min_test_loss, min_index, best_w, best_b, df_summary, loss_history_train, loss_history_test, lr_history = exp44.train_one_lr(initial_lr = 9.52, iterations = 25000)

display(df_summary)
